# %% [markdown]
# # Analysis of Neandertal admixture in early- and present-day humans
# # &mdash; Martin's calls

# %%
cd /mnt/scratch/mateja/Early_modern_humans/nuclear_captures/Archaic_admixture_final/Altai_homozygous_and_YRI_at_high_frequency/

# %% [markdown]
# ## Neandertal admixture in high coverage individuals

# %%
for bed_file in highcov/*.bed; do
    Rscript /mnt/scratch/mp/EMH/calc_proportions_in_individual.R $bed_file
done
# Out:
# In file: highcov/Australian.bed
# ...
# total # of sampled alleles: 476736
# # shared with Africans: 466932
# # shared with archaics: 9804
# proportion shared with archaic: 2.056 %
# 95% C.I.: [ 2.0166%, 2.0972% ]
#
# In file: highcov/Dinka.bed
# ...
# total # of sampled alleles: 476423
# # shared with Africans: 475346
# # shared with archaics: 1077
# proportion shared with archaic: 0.226 %
# 95% C.I.: [ 0.213%, 0.24% ]
#
# In file: highcov/French.bed
# ...
# total # of sampled alleles: 476597
# # shared with Africans: 469214
# # shared with archaics: 7383
# proportion shared with archaic: 1.549 %
# 95% C.I.: [ 1.5144%, 1.5846% ]
#
# In file: highcov/Han.bed
# ...
# total # of sampled alleles: 476590
# # shared with Africans: 467364
# # shared with archaics: 9226
# proportion shared with archaic: 1.936 %
# 95% C.I.: [ 1.8971%, 1.9753% ]
#
# In file: highcov/Karitiana.bed
# ...
# total # of sampled alleles: 476519
# # shared with Africans: 467458
# # shared with archaics: 9061
# ...

# %% [markdown]
# ## Neandertal admixture in Upper-Paleolithic humans

# %%
for bed_file in emh/*.bed; do
    Rscript /mnt/scratch/mp/EMH/calc_proportions_in_individual.R $bed_file
done
# Out:
# In file: emh/AfontovaGora.bed
# ...
# total # of sampled alleles: 58951
# # shared with Africans: 58130
# # shared with archaics: 821
# proportion shared with archaic: 1.393 %
# 95% C.I.: [ 1.3012%, 1.4905% ]
#
# In file: emh/Continenza.bed
# ...
# total # of sampled alleles: 1055
# # shared with Africans: 1034
# # shared with archaics: 21
# proportion shared with archaic: 1.991 %
# 95% C.I.: [ 1.3056%, 3.0238% ]
#
# In file: emh/DolniVestonice13.bed
# ...
# total # of sampled alleles: 22715
# # shared with Africans: 22191
# # shared with archaics: 524
# proportion shared with archaic: 2.307 %
# 95% C.I.: [ 2.1195%, 2.5103% ]
#
# In file: emh/DolniVestonice15.bed
# ...
# total # of sampled alleles: 3625
# # shared with Africans: 3563
# # shared with archaics: 62
# proportion shared with archaic: 1.71 %
# 95% C.I.: [ 1.3365%, 2.1864% ]
#
# In file: emh/DolniVestonice16.bed
# ...
# total # of sampled alleles: 60589
# # shared with Africans: 59336
# # shared with archaics: 1253
# ...

# %% [markdown]
# <br><br><br><br><br>
# # Analysis of Neandertal admixture in early- and present-day humans
# # &mdash; Mateja's calls

# %%
cd /mnt/scratch/mateja/Early_modern_humans/nuclear_captures/Archaic_admixture_final/Test_high_cov_with_Altai_only_positions

# %% [markdown]
# ## Neandertal admixture in high coverage individuals

# %%
for bed_file in High_coverage_individuals/*.bed; do
    Rscript /mnt/scratch/mp/EMH/calc_proportions_in_individual.R $bed_file
done
# Out:
# In file: High_coverage_individuals/Dinka.bed
# ...
# total # of sampled alleles: 476423
# # shared with Africans: 475340
# # shared with archaics: 1083
# proportion shared with archaic: 0.227 %
# 95% C.I.: [ 0.2142%, 0.2412% ]
#
# In file: High_coverage_individuals/French.bed
# ...
# total # of sampled alleles: 476600
# # shared with Africans: 469218
# # shared with archaics: 7382
# proportion shared with archaic: 1.549 %
# 95% C.I.: [ 1.5142%, 1.5843% ]
#
# In file: High_coverage_individuals/Han.bed
# ...
# total # of sampled alleles: 476590
# # shared with Africans: 467328
# # shared with archaics: 9262
# proportion shared with archaic: 1.943 %
# 95% C.I.: [ 1.9046%, 1.983% ]
#
# In file: High_coverage_individuals/Mbuti.bed
# ...
# total # of sampled alleles: 476724
# # shared with Africans: 474111
# # shared with archaics: 2613
# proportion shared with archaic: 0.548 %
# 95% C.I.: [ 0.5276%, 0.5695% ]
#
# In file: High_coverage_individuals/San.bed
# ...
# total # of sampled alleles: 476715
# ...

# %% [markdown]
# ## Neandertal admixture in Upper-Paleolithic humans

# %%
for bed_file in Majority_call_low_coverage_deam_only/*.bed; do
    Rscript /mnt/scratch/mp/EMH/calc_proportions_in_individual.R $bed_file
done
# Out:
# In file: Majority_call_low_coverage_deam_only/Afontova_Gora_deam_L35MQ37_majority_call.bed
# ...
# total # of sampled alleles: 59280
# # shared with Africans: 58097
# # shared with archaics: 1183
# proportion shared with archaic: 1.996 %
# 95% C.I.: [ 1.8861%, 2.1113% ]
#
# In file: Majority_call_low_coverage_deam_only/Dolni_Vestonice_13_deam_L35MQ37_majority_call.bed
# ...
# total # of sampled alleles: 22716
# # shared with Africans: 22194
# # shared with archaics: 522
# proportion shared with archaic: 2.298 %
# 95% C.I.: [ 2.111%, 2.501% ]
#
# In file: Majority_call_low_coverage_deam_only/Dolni_Vestonice_15_deam_L35MQ37_majority_call.bed
# ...
# total # of sampled alleles: 3625
# # shared with Africans: 3562
# # shared with archaics: 63
# proportion shared with archaic: 1.738 %
# 95% C.I.: [ 1.3608%, 2.2173% ]
#
# In file: Majority_call_low_coverage_deam_only/Dolni_Vestonice_16_deam_L35MQ37_majority_call.bed
# ...
# total # of sampled alleles: 60588
# # shared with Africans: 59316
# ...
